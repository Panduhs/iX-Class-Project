# %%
from datetime import datetime

# %%
import pandas as pd
import numpy as np

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
traffic_data = pd.read_csv("data/train_revised.csv")

# %% [markdown]
# # Travel Time Histogram by Origin

# %%
travel_time_data = traffic_data.copy()
travel_time_data['count'] = travel_time_data.groupby('travel_from')['travel_from'].transform('count')
travel_time_data.sort_values(by=["count"], ascending=False, inplace=True)
travel_time_data
# Out:
#        ride_id seat_number payment_method payment_receipt travel_date  \
# 51644    14304           7          Mpesa      AQN7FBUSGP    14-11-17
# 35126    11598           1          Mpesa      CSNIGRGJAM    10-12-17
# 15273     8605           1          Mpesa      XDHPSNNMAG    06-02-18
# 15272     8605          1X          Mpesa      UBBBIAOSC0    06-02-18
# 15271     8605           2          Mpesa      60OTM8AMMD    06-02-18
# ...        ...         ...            ...             ...         ...
# 2379      6686         21A          Mpesa      UNLL8ELVHX    06-12-17
# 1832      6602         24A          Mpesa      1IAWCJCTXT    05-12-17
# 2378      6686         22A          Mpesa      7GEVWRAUBE    06-12-17
# 2566      6686         16A          Mpesa      8AWXTU8FZF    06-12-17
# 19024     9190          1A          Mpesa      BYWAWORQ6U    26-01-18
#
#       travel_time travel_from travel_to car_type  max_capacity  count
# 51644        5:10       Kisii   Nairobi      Bus            49  22607
# 35126        6:50       Kisii   Nairobi  shuttle            11  22607
# 15273        6:40       Kisii   Nairobi  shuttle            11  22607
# 15272        6:40       Kisii   Nairobi  shuttle            11  22607
# 15271        6:40       Kisii   Nairobi  shuttle            11  22607
# ...           ...         ...       ...      ...           ...    ...
# 2379         7:02      Oyugis   Nairobi      Bus            49      5
# 1832         7:02      Oyugis   Nairobi      Bus            49      5
# 2378         7:02      Oyugis   Nairobi      Bus            49      5
# 2566         7:02      Oyugis   Nairobi      Bus            49      5
# 19024        7:02   Kendu Bay   Nairobi      Bus            49      1
#
# [51645 rows x 11 columns]

# %%
# Get only the 5 most popular origin cities
origins = travel_time_data.drop_duplicates(subset=["travel_from"])["travel_from"]
top_origins = origins[:5]
origins
# Out:
# 51644        Kisii
# 27186       Migori
# 38083     Homa Bay
# 42140       Sirare
# 43048        Rongo
# 48601     Kehancha
# 47358       Awendo
# 44813      Kijauri
# 16714       Keroka
# 50852    Nyachenge
# 50891         Rodi
# 45908        Mbita
# 50892       Ndhiwa
# 21641         Sori
# 1127        Keumbu
# 2568        Oyugis
# 19024    Kendu Bay
# Name: travel_from, dtype: object

# %%
def time_to_minutes(time: str):
    h,m = time.split(":")
    return int(h) * 60 + int(m)

# %%
travel_time_data["travel_time_minutes"] = [time_to_minutes(time) for time in travel_time_data["travel_time"]]

# Create consistent number of bins
bins = np.arange(0, 1440, 25)

for og in top_origins:
    # Get all tickets from og
    ticks_from_og = travel_time_data["travel_from"] == og
    ticks = travel_time_data[ticks_from_og]["travel_time_minutes"]
    
    # Plot bars on the chart
    plt.hist(ticks, bins=bins, alpha=0.5, label=og)

# Label up the chart
plt.xlabel("Time of Day (Min)")
plt.ylabel("# of Tickets Sold")
plt.title("Time of Day vs. Tickets Sold by 5 Most Common Origin Cities")
plt.legend()
plt.show()

# %%
# Plot by percentage
for og in origins[:10]:
    # Get all tickets from og
    ticks_from_og = travel_time_data["travel_from"] == og
    ticks = travel_time_data[ticks_from_og]["travel_time_minutes"]
    
    # Weight each bin by total for percentage
    weights = np.ones_like(ticks) / len(ticks)
    plt.hist(ticks, bins=bins, alpha=0.5, label=og, weights=weights)

# Label it up
plt.xlabel("Time of Day (Min)")
plt.ylabel("% of Total Tickets Sold")
plt.title("Time of Day vs. % of Total Tickets Sold by 5 Most Common Origin Cities")
plt.legend()
plt.show()

# %% [markdown]
# # Date vs. Tickets Sold Histogram

# %%
date_traffic_data = traffic_data.copy()
date_traffic_data['count'] = date_traffic_data.groupby('travel_date')['travel_date'].transform('count')
date_traffic_data["travel_date"] = [datetime.strptime(entry, "%d-%m-%y") for entry in date_traffic_data["travel_date"]]
date_traffic_data
# Out:
#        ride_id seat_number payment_method payment_receipt travel_date  \
# 0         1442         15A          Mpesa      UZUEHCBUSO  2017-10-17
# 1         5437         14A          Mpesa      TIHLBUSGTE  2017-11-19
# 2         5710          8B          Mpesa      EQX8Q5G19O  2017-11-26
# 3         5777         19A          Mpesa      SGP18CL0ME  2017-11-27
# 4         5778         11A          Mpesa      BM97HFRGL9  2017-11-27
# ...        ...         ...            ...             ...         ...
# 51640    13826          9B          Mpesa      8V2XDDZR6V  2018-04-20
# 51641    13809         18A          Mpesa      4PEBSVJSNK  2018-04-20
# 51642    13809         17A          Mpesa      LVN64LZDNN  2018-04-20
# 51643    13796         16B          Mpesa      REYBSKTYWN  2018-04-20
# 51644    14304           7          Mpesa      AQN7FBUSGP  2017-11-14
#
#       travel_time travel_from travel_to car_type  max_capacity  count
# 0            7:15      Migori   Nairobi      Bus            49      1
# 1            7:12      Migori   Nairobi      Bus            49      1
# 2            7:05      Keroka   Nairobi      Bus            49      1
# 3            7:10    Homa Bay   Nairobi      Bus            49    305
# 4            7:12      Migori   Nairobi      Bus            49    305
# ...           ...         ...       ...      ...           ...    ...
# 51640        8:00      Awendo   Nairobi      Bus            49    355
# 51641        8:00      Migori   Nairobi      Bus            49    355
# 51642        8:00      Migori   Nairobi      Bus            49    355
# 51643        7:08      Awendo   Nairobi      Bus            49    355
# 51644        5:10       Kisii   Nairobi      Bus            49      1
#
# [51645 rows x 11 columns]

# %%
holidays = pd.DataFrame.from_dict({
    "26-10-17": "Public Holiday",
    "12-12-17": "Jamhuri Day",
    "25-12-17": "Christmas Day",
    "26-12-17": "Boxing Day",
    "01-01-18": "New Year's Day",
    "30-03-18": "Good Friday",
    "02-04-18": "Easter Monday"
}, orient="index", columns=["holiday"])

holidays.index = [datetime.strptime(i, "%d-%m-%y") for i in holidays.index]
holidays
# Out:
#                    holiday
# 2017-10-26  Public Holiday
# 2017-12-12     Jamhuri Day
# 2017-12-25   Christmas Day
# 2017-12-26      Boxing Day
# 2018-01-01  New Year's Day
# 2018-03-30     Good Friday
# 2018-04-02   Easter Monday

# %%
values = date_traffic_data.drop_duplicates(subset=["travel_date"])
values.set_index("travel_date", inplace=True)
values = pd.concat([values, holidays], axis=1)
colors = ["r" if not pd.isna(elem) else "gainsboro" for elem in values["holiday"]]
labels = [elem if not pd.isna(elem) else "" for elem in values["holiday"]]

x = values.index
y = values["count"]

bar = plt.bar(x, y, color=colors, alpha=0.5)
plt.xlabel("Date")
plt.ylabel("# of Tickets Sold")
plt.title("Date vs. # of Tickets Sold with Holidays")
plt.bar_label(bar, labels=labels, rotation="20", fontsize=8)
plt.show()

# %% [markdown]
# # Exploration of Vehicle Type

# %%
vehicle_type_data = traffic_data.copy()

# %%
dests = list(vehicle_type_data["travel_from"].drop_duplicates())
dest_data = pd.DataFrame(0, index=dests, columns=["Bus", "Shuttle"])
dests
# Out:
# ['Migori',
#  'Keroka',
#  'Homa Bay',
#  'Kisii',
#  'Keumbu',
#  'Rongo',
#  'Kijauri',
#  'Oyugis',
#  'Awendo',
#  'Sirare',
#  'Nyachenge',
#  'Kehancha',
#  'Kendu Bay',
#  'Sori',
#  'Rodi',
#  'Mbita',
#  'Ndhiwa']

# %%
# Associate origin city with vehicle type
for i, row in vehicle_type_data.iterrows():
    origin = row["travel_from"]
    car_type = row["car_type"].title()
    
    dest_data.loc[origin, car_type] += 1

# %%
X_axis = np.arange(len(dests))
Y_bus = dest_data.Bus
Y_shuttle = dest_data.Shuttle

# Plot buses and shuttle counts
plt.bar(X_axis - 0.2, Y_bus, 0.4, label="Bus")
plt.bar(X_axis + 0.2, Y_shuttle, 0.4, label="Shuttle")
plt.xticks(X_axis, dests, rotation=40, ha="right")
plt.legend()
plt.xlabel("Origin City")
plt.ylabel("# of Tickets Sold")
plt.title("Origin City vs. # of Tickets Sold by Vehicle Type")
plt.show()

# %%
Y_total = Y_bus + Y_shuttle
Y_bus_perc = Y_bus * 100 / Y_total
Y_shuttle_perc = Y_shuttle * 100 / Y_total

plt.bar(X_axis - 0.2, Y_bus_perc, 0.4, label="Bus")
plt.bar(X_axis + 0.2, Y_shuttle_perc, 0.4, label="Shuttle")
plt.xticks(X_axis, dests, rotation=40, ha="right")
plt.legend()
plt.xlabel("Origin City")
plt.ylabel("% of Total Tickets Sold")
plt.title("Origin City vs. % of Total Tickets Sold by Vehicle Type")
plt.show()

# %% [markdown]
# # Exploration of Ride ID

# %%
id_traffic_data = traffic_data.copy()

# %%
ride_id = id_traffic_data["ride_id"]
print(f"There are {len(ride_id)} tickets")
print(f"There are {len(set(ride_id))} rides")
# Out:
# There are 51645 tickets
# There are 6249 rides

# %%
id_traffic_data.drop_duplicates(subset="ride_id", inplace=True)
id_traffic_data
# Out:
#        ride_id seat_number payment_method payment_receipt travel_date  \
# 0         1442         15A          Mpesa      UZUEHCBUSO    17-10-17
# 1         5437         14A          Mpesa      TIHLBUSGTE    19-11-17
# 2         5710          8B          Mpesa      EQX8Q5G19O    26-11-17
# 3         5777         19A          Mpesa      SGP18CL0ME    27-11-17
# 4         5778         11A          Mpesa      BM97HFRGL9    27-11-17
# ...        ...         ...            ...             ...         ...
# 51575    13812          2B          Mpesa      FSAA2XB4WX    20-04-18
# 51605    13813         14B          Mpesa      TSOPCEGOKH    20-04-18
# 51639    13825         24A          Mpesa      B3R9XWCV9O    20-04-18
# 51640    13826          9B          Mpesa      8V2XDDZR6V    20-04-18
# 51644    14304           7          Mpesa      AQN7FBUSGP    14-11-17
#
#       travel_time travel_from travel_to car_type  max_capacity
# 0            7:15      Migori   Nairobi      Bus            49
# 1            7:12      Migori   Nairobi      Bus            49
# 2            7:05      Keroka   Nairobi      Bus            49
# 3            7:10    Homa Bay   Nairobi      Bus            49
# 4            7:12      Migori   Nairobi      Bus            49
# ...           ...         ...       ...      ...           ...
# 51575       23:10      Ndhiwa   Nairobi      Bus            49
# 51605        7:05      Ndhiwa   Nairobi      Bus            49
# 51639        7:09       Rongo   Nairobi      Bus            49
# 51640        8:00      Awendo   Nairobi      Bus            49
# 51644        5:10       Kisii   Nairobi      Bus            49
#
# [6249 rows x 10 columns]

# %%
id_traffic_data["time_in_minutes"] = [time_to_minutes(entry) for entry in id_traffic_data.travel_time]

plt.hist(id_traffic_data["time_in_minutes"], bins=100)
plt.xlabel("Time of Day (Min)")
plt.ylabel("# of Rides")
plt.title("Time of Day vs. # of Rides")
plt.show()

# %% [markdown]
# <h4>Looks like the graph looks more or less the same between rides and tickets sold</h4>

# %% [markdown]
# # How much is the capacity of buses/shuttles used?

# %%
cap_traffic_data = traffic_data.copy()

# %%
def get_percent(row):
    return row["count"] / row["max_capacity"]

# %%
# Split into bus and shuttle data
bus_data = cap_traffic_data[cap_traffic_data.car_type == "Bus"].copy()
shuttle_data = cap_traffic_data[cap_traffic_data.car_type == "shuttle"].copy()

for df in [bus_data, shuttle_data]:
    # Get tickets sold per ride
    df['count'] = df.groupby('ride_id')['ride_id'].transform('count')

    # Get just the rides
    df.drop_duplicates(subset="ride_id", inplace=True)

    # Create column for % capacity used
    df["%_capacity"] = df.apply(get_percent, axis=1)

bus_data
# Out:
#        ride_id seat_number payment_method payment_receipt travel_date  \
# 0         1442         15A          Mpesa      UZUEHCBUSO    17-10-17
# 1         5437         14A          Mpesa      TIHLBUSGTE    19-11-17
# 2         5710          8B          Mpesa      EQX8Q5G19O    26-11-17
# 3         5777         19A          Mpesa      SGP18CL0ME    27-11-17
# 4         5778         11A          Mpesa      BM97HFRGL9    27-11-17
# ...        ...         ...            ...             ...         ...
# 51575    13812          2B          Mpesa      FSAA2XB4WX    20-04-18
# 51605    13813         14B          Mpesa      TSOPCEGOKH    20-04-18
# 51639    13825         24A          Mpesa      B3R9XWCV9O    20-04-18
# 51640    13826          9B          Mpesa      8V2XDDZR6V    20-04-18
# 51644    14304           7          Mpesa      AQN7FBUSGP    14-11-17
#
#       travel_time travel_from travel_to car_type  max_capacity  count  \
# 0            7:15      Migori   Nairobi      Bus            49      1
# 1            7:12      Migori   Nairobi      Bus            49      1
# 2            7:05      Keroka   Nairobi      Bus            49      1
# 3            7:10    Homa Bay   Nairobi      Bus            49      5
# 4            7:12      Migori   Nairobi      Bus            49     31
# ...           ...         ...       ...      ...           ...    ...
# 51575       23:10      Ndhiwa   Nairobi      Bus            49     11
# 51605        7:05      Ndhiwa   Nairobi      Bus            49     11
# 51639        7:09       Rongo   Nairobi      Bus            49      1
# 51640        8:00      Awendo   Nairobi      Bus            49      1
# 51644        5:10       Kisii   Nairobi      Bus            49      1
#
#        %_capacity
# 0        0.020408
# 1        0.020408
# 2        0.020408
# 3        0.102041
# 4        0.632653
# ...           ...
# 51575    0.224490
# 51605    0.224490
# 51639    0.020408
# 51640    0.020408
# 51644    0.020408
#
# [3189 rows x 12 columns]

# %%
bus_stats = bus_data["%_capacity"]
bus_stats.describe()
# Out:
# count    3189.000000
# mean        0.204690
# std         0.227055
# min         0.020408
# 25%         0.040816
# 50%         0.102041
# 75%         0.285714
# max         1.020408
# Name: %_capacity, dtype: float64

# %%
shuttle_stats = shuttle_data["%_capacity"]
shuttle_stats.describe()
# Out:
# count    3060.000000
# mean        0.584076
# std         0.370262
# min         0.090909
# 25%         0.181818
# 50%         0.727273
# 75%         0.909091
# max         1.090909
# Name: %_capacity, dtype: float64

# %%
bus_data[bus_data["%_capacity"] > 1]
# Out:
#        ride_id seat_number payment_method payment_receipt travel_date  \
# 14020     8454         18A          Mpesa      RPOXVAJVME    09-01-18
#
#       travel_time travel_from travel_to car_type  max_capacity  count  \
# 14020        7:00      Sirare   Nairobi      Bus            49     50
#
#        %_capacity
# 14020    1.020408

# %%
traffic_data[traffic_data["ride_id"] == 8545].sort_values(by="seat_number")
# Out:
#        ride_id seat_number payment_method payment_receipt travel_date  \
# 14689     8545         10A          Mpesa      1T8TTTXQPR    11-01-18
# 14653     8545         10B          Mpesa      R5B9ZMVPQW    11-01-18
# 14647     8545         11A          Mpesa      KHY2D4XCX9    11-01-18
# 14719     8545         11B          Mpesa      PUMZPS5KHA    11-01-18
# 14648     8545         12A          Mpesa      9JPKOYZTX6    11-01-18
# 14654     8545         12B          Mpesa      MORXLDKIFJ    11-01-18
# 14672     8545         13A          Mpesa      PD4M87NK8J    11-01-18
# 14708     8545         13B          Mpesa      QNC8V30UD3    11-01-18
# 14671     8545         14A          Mpesa      4CBCHSHOH3    11-01-18
# 14677     8545         14B          Mpesa      8JUHVPUNSX    11-01-18
# 14668     8545         15A          Mpesa      MG8JUBJT8T    11-01-18
# 14707     8545         15B          Mpesa      P8YKWZS7QZ    11-01-18
# 14684     8545         16A          Mpesa      NQBRVY4TS1    11-01-18
# 14715     8545         16B          Mpesa      XONAQMTUFS    11-01-18
# 14698     8545         17A          Mpesa      OLVSPC1PGY    11-01-18
# 14687     8545         17B          Mpesa      W4SC1E7LUQ    11-01-18
# 14697     8545         18A          Mpesa      CTWRFGSBED    11-01-18
# 14710     8545         18B          Mpesa      VLSOC1O4WY    11-01-18
# 14679     8545         19A          Mpesa      FLAZ2U0GOG    11-01-18
# 14714     8545         19B          Mpesa      SH4LH7EKVF    11-01-18
# 14695     8545          1A          Mpesa      KBMX1YMBG3    11-01-18
# 14694     8545          1B          Mpesa      UENHSKZVWV    11-01-18
# 14666     8545         20A          Mpesa      OQFT9OKDGQ    11-01-18
# 14670     8545         20B          Mpesa      VITU93UDPW    11-01-18
# 14706     8545         21A          Mpesa      WD2RQIP6RF    11-01-18
# 14680     8545         21B          Mpesa      GK4M3YVGHD    11-01-18
# 14673     8545         22A          Mpesa      NUQ89BH1NW    11-01-18
# 14704     8545         22B          Mpesa      9ZSB24MRVK    11-01-18
# 14686     8545         23A          Mpesa      3SSE9AHT4B    11-01-18
# 14691     8545         23B          Mpesa      51RN9MBPKO    11-01-18
# 14713     8545         24A          Mpesa      Z2X4PHGL3C    11-01-18
# 14690     8545         24B          Mpesa      EHEJYVRGXQ    11-01-18
# 14709     8545          25          Mpesa      CDJRFCCD0U    11-01-18
# 14660     8545          2B          Mpesa      XBLWGDLYET    11-01-18
# 14712     8545          3A          Mpesa      4KJZDYO0BQ    11-01-18
# 14644     8545          3B          Mpesa      MZQLP03CVK    11-01-18
# 14711     8545          4A          Mpesa      28S4EIMPZX    11-01-18
# 14645     8545          4B          Mpesa      XU4AW42FBO    11-01-18
# 14674     8545          5A          Mpesa      O3QMOE0GY2    11-01-18
# 14667     8545          5B          Mpesa      WCTOQWMS70    11-01-18
# 14676     8545          6A          Mpesa      Y853GASDQI    11-01-18
# 14659     8545          6B          Mpesa      T2CB0MFZM0    11-01-18
# 14652     8545          7A          Mpesa      MXBFKT1VX1    11-01-18
# 14646     8545          7B          Mpesa      8GUSLLSRGQ    11-01-18
# 14651     8545          8A          Mpesa      RRGX9EMANO    11-01-18
# 14693     8545          8B          Mpesa      X9ASNW7HBE    11-01-18
# 14669     8545          9A          Mpesa      78YTZZWZQ9    11-01-18
# 14663     8545          9B          Mpesa      XRVQK3MKKB    11-01-18
#
#       travel_time travel_from travel_to car_type  max_capacity
# 14689        7:00      Sirare   Nairobi      Bus            49
# 14653        7:00      Sirare   Nairobi      Bus            49
# 14647        7:00      Sirare   Nairobi      Bus            49
# 14719        7:00      Sirare   Nairobi      Bus            49
# 14648        7:00      Sirare   Nairobi      Bus            49
# 14654        7:00      Sirare   Nairobi      Bus            49
# 14672        7:00      Sirare   Nairobi      Bus            49
# 14708        7:00      Sirare   Nairobi      Bus            49
# 14671        7:00      Sirare   Nairobi      Bus            49
# 14677        7:00      Sirare   Nairobi      Bus            49
# 14668        7:00      Sirare   Nairobi      Bus            49
# 14707        7:00      Sirare   Nairobi      Bus            49
# 14684        7:00      Sirare   Nairobi      Bus            49
# 14715        7:00      Sirare   Nairobi      Bus            49
# 14698        7:00      Sirare   Nairobi      Bus            49
# 14687        7:00      Sirare   Nairobi      Bus            49
# 14697        7:00      Sirare   Nairobi      Bus            49
# 14710        7:00      Sirare   Nairobi      Bus            49
# 14679        7:00      Sirare   Nairobi      Bus            49
# 14714        7:00      Sirare   Nairobi      Bus            49
# 14695        7:00      Sirare   Nairobi      Bus            49
# 14694        7:00      Sirare   Nairobi      Bus            49
# 14666        7:00      Sirare   Nairobi      Bus            49
# 14670        7:00      Sirare   Nairobi      Bus            49
# 14706        7:00      Sirare   Nairobi      Bus            49
# 14680        7:00      Sirare   Nairobi      Bus            49
# 14673        7:00      Sirare   Nairobi      Bus            49
# 14704        7:00      Sirare   Nairobi      Bus            49
# 14686        7:00      Sirare   Nairobi      Bus            49
# 14691        7:00      Sirare   Nairobi      Bus            49
# 14713        7:00      Sirare   Nairobi      Bus            49
# 14690        7:00      Sirare   Nairobi      Bus            49
# 14709        7:00      Sirare   Nairobi      Bus            49
# 14660        7:00      Sirare   Nairobi      Bus            49
# 14712        7:00      Sirare   Nairobi      Bus            49
# 14644        7:00      Sirare   Nairobi      Bus            49
# 14711        7:00      Sirare   Nairobi      Bus            49
# 14645        7:00      Sirare   Nairobi      Bus            49
# 14674        7:00      Sirare   Nairobi      Bus            49
# 14667        7:00      Sirare   Nairobi      Bus            49
# 14676        7:00      Sirare   Nairobi      Bus            49
# 14659        7:00      Sirare   Nairobi      Bus            49
# 14652        7:00      Sirare   Nairobi      Bus            49
# 14646        7:00      Sirare   Nairobi      Bus            49
# 14651        7:00      Sirare   Nairobi      Bus            49
# 14693        7:00      Sirare   Nairobi      Bus            49
# 14669        7:00      Sirare   Nairobi      Bus            49
# 14663        7:00      Sirare   Nairobi      Bus            49

# %%
shuttle_data[shuttle_data["%_capacity"] > 1]
# Out:
#        ride_id seat_number payment_method payment_receipt travel_date  \
# 11858     8124          10          Mpesa      0JV6LE7DLQ    13-02-18
# 14549     8528           4          Mpesa      T90LXAJYRJ    07-02-18
# 15438     8642           3          Mpesa      GKIMSEN6HI    05-02-18
# 15506     8651           2          Mpesa      G2AXAAGT2G    05-02-18
# 16382     8773           4          Mpesa      OMJWGXF3KR    04-02-18
# 17846     9011           3          Mpesa      2S705PYUNW    31-01-18
# 27920    10689           9          Mpesa      J3KWUYG5FQ    20-12-17
# 29118    10847          1X          Mpesa      OG36YBKDOZ    19-12-17
# 32321    11279          1X          Mpesa      TPHTQGQ2L9    14-12-17
# 35200    11612           7          Mpesa      HONXUTCIAA    10-12-17
# 37496    11889           1          Mpesa      WDJHDKEBNG    07-12-17
# 40623    12307          10           Cash      MCG3B9GENP    16-03-18
#
#       travel_time travel_from travel_to car_type  max_capacity  count  \
# 11858        7:00       Kisii   Nairobi  shuttle            11     12
# 14549        9:30       Kisii   Nairobi  shuttle            11     12
# 15438       10:30       Kisii   Nairobi  shuttle            11     12
# 15506        9:10       Kisii   Nairobi  shuttle            11     12
# 16382       10:51       Kisii   Nairobi  shuttle            11     12
# 17846        9:50       Kisii   Nairobi  shuttle            11     12
# 27920       10:00       Kisii   Nairobi  shuttle            11     12
# 29118        7:20       Kisii   Nairobi  shuttle            11     12
# 32321       10:57       Kisii   Nairobi  shuttle            11     12
# 35200       11:05       Kisii   Nairobi  shuttle            11     12
# 37496       10:40       Kisii   Nairobi  shuttle            11     12
# 40623        5:00      Keroka   Nairobi  shuttle            11     12
#
#        %_capacity
# 11858    1.090909
# 14549    1.090909
# 15438    1.090909
# 15506    1.090909
# 16382    1.090909
# 17846    1.090909
# 27920    1.090909
# 29118    1.090909
# 32321    1.090909
# 35200    1.090909
# 37496    1.090909
# 40623    1.090909

# %% [markdown]
# <h4>Everything looks normal, and it looks shuttles tend to be more filled out than buses, which makes sense.  However, ride 8454 and a number of shuttles sold more tickets than their capacity</h4>

# %% [markdown]
# # Weekdays vs. Tickets Sold

# %%
wd_data = traffic_data.copy()

# %%
wd_data["travel_date"] = [datetime.strptime(entry, "%d-%m-%y") for entry in wd_data["travel_date"]]
wd_data["weekday"] = [date.weekday() for date in wd_data["travel_date"]]

wd_data
# Out:
#        ride_id seat_number payment_method payment_receipt travel_date  \
# 0         1442         15A          Mpesa      UZUEHCBUSO  2017-10-17
# 1         5437         14A          Mpesa      TIHLBUSGTE  2017-11-19
# 2         5710          8B          Mpesa      EQX8Q5G19O  2017-11-26
# 3         5777         19A          Mpesa      SGP18CL0ME  2017-11-27
# 4         5778         11A          Mpesa      BM97HFRGL9  2017-11-27
# ...        ...         ...            ...             ...         ...
# 51640    13826          9B          Mpesa      8V2XDDZR6V  2018-04-20
# 51641    13809         18A          Mpesa      4PEBSVJSNK  2018-04-20
# 51642    13809         17A          Mpesa      LVN64LZDNN  2018-04-20
# 51643    13796         16B          Mpesa      REYBSKTYWN  2018-04-20
# 51644    14304           7          Mpesa      AQN7FBUSGP  2017-11-14
#
#       travel_time travel_from travel_to car_type  max_capacity  weekday
# 0            7:15      Migori   Nairobi      Bus            49        1
# 1            7:12      Migori   Nairobi      Bus            49        6
# 2            7:05      Keroka   Nairobi      Bus            49        6
# 3            7:10    Homa Bay   Nairobi      Bus            49        0
# 4            7:12      Migori   Nairobi      Bus            49        0
# ...           ...         ...       ...      ...           ...      ...
# 51640        8:00      Awendo   Nairobi      Bus            49        4
# 51641        8:00      Migori   Nairobi      Bus            49        4
# 51642        8:00      Migori   Nairobi      Bus            49        4
# 51643        7:08      Awendo   Nairobi      Bus            49        4
# 51644        5:10       Kisii   Nairobi      Bus            49        1
#
# [51645 rows x 11 columns]

# %%
days = ["Sunday", "Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday"]

plt.hist(wd_data.weekday, bins=7, edgecolor="black")
plt.xticks(range(7), labels=days, rotation="30")
plt.show()

# %%
wd_data["travel_time_minutes"] = [time_to_minutes(time) for time in wd_data["travel_time"]]

bins = np.arange(0, 1440, 25)

for day in range(7):
    # Get tickets by day
    on_this_day = wd_data["weekday"] == day
    ticks = wd_data[on_this_day]["travel_time_minutes"]
    
    # Add each origin city to histogram
    plt.hist(ticks, bins=bins, alpha=0.5, label=days[day])
    
# Label up the chart
plt.xlabel("Time of Day (Min)")
plt.ylabel("# of Tickets Sold")
plt.title(f"Time of Day vs. Tickets Sold by Day of Week")
plt.legend()
plt.show()

# %%
# Get them by percentage
for day in range(7):
    # Get tickets by day
    on_this_day = wd_data["weekday"] == day
    ticks = wd_data[on_this_day]["travel_time_minutes"]
    
    # Add each origin city to histogram
    weights = np.ones_like(ticks) / len(ticks)
    plt.hist(ticks, bins=bins, alpha=0.5, label=days[day], weights=weights)
    
# Label up the chart
plt.xlabel("Time of Day (Min)")
plt.ylabel("% of Total Tickets Sold")
plt.title(f"Time of Day vs. % of Total Tickets Sold by Day of Week")
plt.legend()
plt.show()
